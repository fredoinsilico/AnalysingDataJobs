# %%
import pandas as pd
import numpy as np
df = pd.read_csv('./linkedin-jobs-africa.csv')
df.head(1)

# %%
df.shape
# Out:
# (2872, 9)

# %%
# localizacion = df['location']
# len(localizacion)

df['salary'].isna().sum()

# %%
print(df["onsite_remote"].unique())

# %%
import matplotlib
import matplotlib.pyplot as plt

# Obtener los valores únicos y sus frecuencias en la columna "onsite_remote"
values, counts = np.unique(df["onsite_remote"], return_counts=True)

# Crear un gráfico de barras con las frecuencias de cada valor
plt.bar(values, counts)

# Agregar títulos y etiquetas de eje
plt.title("Frecuencia modalidad Trabajo")
plt.xlabel("Modalidad")
plt.ylabel("Conteo")

# Mostrar el gráfico
plt.show()

# %%
counts = df["onsite_remote"].value_counts()
counts
# Out:
# onsite    972
# remote    950
# hybrid    950
# Name: onsite_remote, dtype: int64
